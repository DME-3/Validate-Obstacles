# %%
import json

# Load the provided JSON file
file_path = 'assets/index.json'

with open(file_path, 'r') as file:
    data = json.load(file)

total_files = 0
total_size = 0

for dataset in data.get('datasets', []):
    files = dataset.get('files', [])
    total_files += len(files)
    total_size += sum(int(file['size']) for file in files)

total_files, total_size
# Out:
# (35860, 3120908957711)

# %%
# Create a dictionary for quick lookup from the JSON data (much quicker than recursively looking up in the JSON)

def create_lookup_dict(json_data):

    lookup_dict = {}
    for dataset in json_data.get('datasets', []):
        for file in dataset.get('files', []):
            lookup_dict[file['name']] = (file['size'], file['timestamp'])
    return lookup_dict

# Create a lookup dictionary
lookup_dict = create_lookup_dict(data)

# %%
def parse_coordinates_from_filename(filename):
    """
    Extract easting and northing values from the file name.
    For example, from '3dm_32_280_5656_1_nw.laz', it will extract (32280, 5656).
    """
    parts = filename.split('_')
    easting = int(parts[1] + parts[2])
    northing = int(parts[3])
    return easting, northing

def calculate_zone_files_and_size(files, max_easting, max_northing):
    """
    Calculate the number of files and total size for each zone based on the given limits.
    """
    zones = {
        'zone_1': {'count': 0, 'size': 0},
        'zone_2': {'count': 0, 'size': 0},
        'zone_3': {'count': 0, 'size': 0},
        'zone_4': {'count': 0, 'size': 0}
    }

    for file in files:
        size = int(file['size'])
        easting, northing = parse_coordinates_from_filename(file['name'])

        if easting < max_easting and northing < max_northing:
            zones['zone_1']['count'] += 1
            zones['zone_1']['size'] += size
        elif easting < max_easting and northing >= max_northing:
            zones['zone_2']['count'] += 1
            zones['zone_2']['size'] += size
        elif easting >= max_easting and northing >= max_northing:
            zones['zone_3']['count'] += 1
            zones['zone_3']['size'] += size
        else: # easting >= max_easting and northing >= max_northing
            zones['zone_4']['count'] += 1
            zones['zone_4']['size'] += size

    return zones

def print_zone_results(zones):
    """
    Print the results for each zone.
    """
    for zone, data in zones.items():
        size_gb = data['size'] / (1024**3)  # Convert bytes to gigabytes
        print(f"{zone.upper()}: Number of files = {data['count']}, Total size = {size_gb:.2f} GB")

# %%
def calculate_size(filenames, lookup_dict = lookup_dict):
    total_files = 0
    total_size = 0

    for filename in filenames:
        file_info = lookup_dict.get(filename)
        if file_info:
            total_files += 1
            total_size += int(file_info[0])  # file_info[0] is the size

    return total_files, round(total_size / (1024**3), 2)  # Size in GB

# %%
def find_file_info(filename, json_data):
    """
    Search for a file in the JSON data and return its size and timestamp if found.
    If not found, return False.
    """
    for dataset in json_data.get('datasets', []):
        for file in dataset.get('files', []):
            if file['name'] == filename:
                return file['size'], file['timestamp']

    return False

# %%
# Find min max easting and northing for a list of names

def find_minmax_EN(filenames):

  min_easting, min_northing = parse_coordinates_from_filename(filenames[0])
  max_easting = min_easting
  max_northing = min_northing

  for file in filenames:

    easting, northing = parse_coordinates_from_filename(file)

    if easting < min_easting: min_easting = easting
    if northing < min_northing: min_northing = northing
    if easting > max_easting: max_easting = easting
    if northing > max_northing: max_northing = northing

  return min_easting, max_easting, min_northing, max_northing

#Segregate files into four zones based on the given limits and return their filenames.

def segregate_files_into_main_zones(files, max_easting, max_northing):
    """
    
    """

    zones = {
        'zone_1': [],
        'zone_2': [],
        'zone_3': [],
        'zone_4': []
    }

    for file in files:
        filename = file['name']
        easting, northing = parse_coordinates_from_filename(filename)

        if easting < max_easting and northing < max_northing:
            zones[list(zones.keys())[0]].append(filename)
        elif easting < max_easting and northing >= max_northing:
            zones[list(zones.keys())[1]].append(filename)
        elif easting >= max_easting and northing >= max_northing:
            zones[list(zones.keys())[2]].append(filename)
        else: # easting >= max_easting and northing >= max_northing
            zones[list(zones.keys())[3]].append(filename)

    return zones

def segregate_files_into_sub_zones(files, easting_range, northing_range, best_easting, best_northing, idx):
    """
    Segregate files into four subzones based on the given limits and return their filenames.
    """
    zones = {
          'zone_%s.1'%(idx): [],
          'zone_%s.2'%(idx): [],
          'zone_%s.3'%(idx): [],
          'zone_%s.4'%(idx): [],
      }

    for file in files:
        filename = file['name']
        easting, northing = parse_coordinates_from_filename(filename)

        if easting_range.start <= easting < best_easting and northing_range.start <= northing < best_northing:
            zones[list(zones.keys())[0]].append(filename)
        elif easting_range.start <= easting < best_easting and best_northing <= northing <= northing_range.stop :
            zones[list(zones.keys())[1]].append(filename)
        elif best_easting <= easting <= easting_range.stop and best_northing <= northing <= northing_range.stop:
            zones[list(zones.keys())[2]].append(filename)
        elif best_easting <= easting <= easting_range.stop and northing_range.start <= northing < best_northing:
            zones[list(zones.keys())[3]].append(filename)

    return zones

def write_zone_files(zones):
    """
    Write the filenames of each zone into separate text files.
    """
    for zone, filenames in zones.items():
        with open(f'{zone}_files.txt', 'w') as file:
            for filename in filenames:
                file.write(filename + '\n')

def calculate_zone_size(files, easting_start, easting_limit, northing_start, northing_limit):

  zone_size = 0

  for east in range(easting_start, easting_limit, 10):
    for north in range(northing_start, northing_limit, 10):

      tentative_filename = f'3dm_{str(east)[0:2]}_{str(east)[2:]}_{str(north)}_1_nw.laz'

      if tentative_filename in lookup_dict:

        size = int(lookup_dict[tentative_filename][0])

        zone_size += size

  return zone_size

def find_balanced_zones(files, easting_range, northing_range):
    best_balance = float('inf')
    best_easting = None
    best_northing = None

    for easting_limit in easting_range:
        for northing_limit in northing_range:

          tentative_zone_1 = calculate_zone_size(files, easting_range.start, easting_limit, northing_range.start, northing_limit)
          tentative_zone_2 = calculate_zone_size(files, easting_range.start, easting_limit, northing_limit, northing_range.stop)
          tentative_zone_3 = calculate_zone_size(files, easting_limit, easting_range.stop, northing_limit, northing_range.stop)
          tentative_zone_4 = calculate_zone_size(files, easting_limit, easting_range.stop, northing_range.start, northing_limit)

          sizes = [tentative_zone_1, tentative_zone_2, tentative_zone_3, tentative_zone_4]

          balance = max(sizes) - min(sizes)  # Example balance metric

          if balance < best_balance:
              best_balance = balance
              best_easting = easting_limit
              best_northing = northing_limit

    return best_easting, best_northing, best_balance

# %% [markdown]
# # Divide in zones and subzones

# %%
# Find the best division for the 4 main zones

min_easting, max_easting, min_northing, max_northing = find_minmax_EN(list(lookup_dict.keys()))

easting_range = range(min_easting, max_easting, 10) # step at 10 speeds up finding the best division
northing_range = range(min_northing, max_northing, 10)

print('Finding the 4 balanced main zones...')

all_files = []
for dataset in data.get('datasets', []):
    all_files.extend(dataset.get('files', []))

best_easting, best_northing, _ = find_balanced_zones(all_files, easting_range, northing_range)

print(f"Best balance at Easting: {best_easting}, Northing: {best_northing} for the 4 main zones")
print('\n')

# Create our 4 main zones

main_zones = segregate_files_into_main_zones(all_files, best_easting, best_northing)

idx = 1
sub_zones = []
number_of_files = 0
total_size = 0
coordinates = []

for zone in main_zones: # for each main zone

  # Find the best division in 4 subzones

  min_easting, max_easting, min_northing, max_northing = find_minmax_EN(main_zones[zone])

  easting_range = range(min_easting, max_easting, 10)
  northing_range = range(min_northing, max_northing, 10)

  print(f'Finding balanced subzones of main zone {idx}...')

  best_easting, best_northing, _ = find_balanced_zones(main_zones[zone], easting_range, northing_range)

  print(f'For main zone {zone}, the best balance is obtained for: Easting: {best_easting}, Northing: {best_northing}')

  # Create the subzones and write files

  sub_zones.append(segregate_files_into_sub_zones(all_files, easting_range, northing_range, best_easting, best_northing, idx))

  subtotal_number_of_files = 0
  subtotal_size = 0

  # List of coordinates for generating a KML or SHP
  coordinates.append((easting_range.start, best_easting, northing_range.start, best_northing)) # subzone x.1
  coordinates.append((easting_range.start, best_easting, best_northing, northing_range.stop)) # subzone x.2
  coordinates.append((best_easting, easting_range.stop, best_northing, northing_range.stop)) # subzone x.3
  coordinates.append((best_easting, easting_range.stop, northing_range.start, best_northing)) # subzone x.4

  for j in range(4): # For each of the 4 subzones

    files_number = len(list(sub_zones[idx-1].values())[j])
    sub_size = calculate_size(list(sub_zones[idx-1].values())[j])[1]

    subtotal_number_of_files += files_number
    subtotal_size += sub_size

    print(f'{str(files_number)} files in {list(sub_zones[idx-1].keys())[j]}, size = {str(sub_size)} GB')

  number_of_files += subtotal_number_of_files
  total_size += subtotal_size

  write_zone_files(sub_zones[idx-1])

  idx += 1

  print('\n')

print('- Verification - ')
print('\n')
print(f'Total number of files after processing: {number_of_files}, cumulated size: {total_size}')
print(f'Comparison basis from original index file: {total_files}, {str(round(sum(int(file_info[0]) for file_info in lookup_dict.values()) / (1024**3), 2))} GB')
# Out:
# Finding the 4 balanced main zones...
# Best balance at Easting: 32400, Northing: 5686 for the 4 main zones
#
#
# Finding balanced subzones of main zone 1...
# For main zone zone_1, the best balance is obtained for: Easting: 32330, Northing: 5636
# 1692 files in zone_1.1, size = 287.82 GB
# 1996 files in zone_1.2, size = 140.43 GB
# 3500 files in zone_1.3, size = 327.18 GB
# 2416 files in zone_1.4, size = 272.47 GB
#
#
# Finding balanced subzones of main zone 2...
# For main zone zone_2, the best balance is obtained for: Easting: 32378, Northing: 5726
# 3012 files in zone_2.1, size = 194.44 GB
# 3396 files in zone_2.2, size = 140.96 GB
# 1572 files in zone_2.3, size = 69.91 GB
# 880 files in zone_2.4, size = 123.63 GB
#
#
# Finding balanced subzones of main zone 3...
# For main zone zone_3, the best balance is obtained for: Easting: 32470, Northing: 5726
# 2800 files in zone_3.1, size = 303.22 GB
# 4828 files in zone_3.2, size = 212.89 GB
# 3972 files in zone_3.3, size = 261.87 GB
# 1680 files in zone_3.4, size = 116.03 GB
#
#
# Finding balanced subzones of main zone 4...
# For main zone zone_4, the best balance is obtained for: Easting: 32430, Northing: 5674
# 1328 files in zone_4.1, size = 146.07 GB
# 360 files in zone_4.2, size = 68.33 GB
# 576 files in zone_4.3, size = 86.08 GB
# 1852 files in zone_4.4, size = 155.24 GB
#
#
# - Verification -
#
#
# Total number of files after processing: 35860, cumulated size: 2906.57
# Comparison basis from original index file: 35860, 2906.57 GB

# %%
# !zip results.zip *.txt
# Out:
#   adding: zone_1.1_files.txt (deflated 90%)
#   adding: zone_1.2_files.txt (deflated 90%)
#   adding: zone_1.3_files.txt (deflated 90%)
#   adding: zone_1.4_files.txt (deflated 90%)
#   adding: zone_2.1_files.txt (deflated 90%)
#   adding: zone_2.2_files.txt (deflated 89%)
#   adding: zone_2.3_files.txt (deflated 90%)
#   adding: zone_2.4_files.txt (deflated 90%)
#   adding: zone_3.1_files.txt (deflated 90%)
#   adding: zone_3.2_files.txt (deflated 90%)
#   adding: zone_3.3_files.txt (deflated 90%)
#   adding: zone_3.4_files.txt (deflated 90%)
#   adding: zone_4.1_files.txt (deflated 90%)
#   adding: zone_4.2_files.txt (deflated 91%)
#   adding: zone_4.3_files.txt (deflated 91%)
#   adding: zone_4.4_files.txt (deflated 90%)

# %% [markdown]
# # Generate a KML file showing our division in subzones

# %%
import simplekml
import utm

def utm_to_latlon(x, y):
    # Convert lat/lon to UTM coordinates
    lat, lon = utm.to_latlon((x - 32000)*1000, y*1000, 32, 'U')

    return lat, lon

def create_kml_with_squares(coordinates, kml_filename):
    """
    Create a KML file with squares from a list of coordinates.
    """
    kml = simplekml.Kml()

    for min_easting, max_easting, min_northing, max_northing in coordinates:
        # Convert each corner to WGS84
        min_lat, min_lon = utm_to_latlon(min_easting, min_northing)
        max_lat, max_lon = utm_to_latlon(max_easting, max_northing)

        # Create square as a polygon
        pol = kml.newpolygon(name="Square",
                             outerboundaryis=[(min_lon, min_lat),
                                              (min_lon, max_lat),
                                              (max_lon, max_lat),
                                              (max_lon, min_lat),
                                              (min_lon, min_lat)])
        pol.style.linestyle.color = simplekml.Color.red
        pol.style.linestyle.width = 3
        pol.style.polystyle.color = simplekml.Color.changealphaint(100, simplekml.Color.green)

    kml.save(kml_filename)

# %%
create_kml_with_squares(coordinates, 'NRW_division.kml')

# %% [markdown]
# # Download

# %%
url_prefix = 'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/'

download_list = [url_prefix + item for item in sub_zones[0]['zone_1.1']]

# %%
import requests
from time import sleep
import os

def download_file(url, directory, attempt=1, max_attempts=5):
    """Download a file with retries on failure and save it to a specified directory."""
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Raise an error for bad status codes

        file_name = url.split('/')[-1]
        file_path = os.path.join(directory, file_name)  # Combine the directory with the file name

        with open(file_path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded {file_name} to {directory}")

    except requests.RequestException as e:
        if attempt < max_attempts:
            print(f"Attempt {attempt} failed for {url}. Retrying...")
            sleep(1)  # Wait for 1 second before retrying
            download_file(url, directory, attempt + 1, max_attempts)
        else:
            print(f"Failed to download {url} after {max_attempts} attempts.")

download_directory = "/Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/"

# Create the directory if it doesn't exist
if not os.path.exists(download_directory):
    os.makedirs(download_directory)

# Download each file
for url in download_list:
    download_file(url, download_directory)
# Out:
# Downloaded 3dm_32_286_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_286_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_286_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_286_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_287_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_287_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_287_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_287_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_288_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_289_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_290_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Attempt 1 failed for https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5623_1_nw.laz. Retrying...
# Downloaded 3dm_32_291_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_291_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_292_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_293_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_294_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_295_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_296_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_297_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_298_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_299_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_300_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_301_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_302_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_303_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_304_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_305_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_306_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_307_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_308_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# ...
# Downloaded 3dm_32_326_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_326_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5582_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5583_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5584_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5585_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5586_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5587_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5588_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5589_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5590_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5591_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5592_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5593_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5594_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5595_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_327_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5582_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5583_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5584_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5585_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5586_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5587_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5588_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5589_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5590_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5591_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5592_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5593_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5594_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5595_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_328_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5582_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5583_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5584_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5585_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5586_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5587_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5588_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5589_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5590_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5591_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5592_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5593_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5594_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5595_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5596_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5597_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5598_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5599_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5600_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5601_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5602_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5603_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5604_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5605_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5606_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5607_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5608_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5609_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5610_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5611_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5612_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5613_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5614_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5615_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5616_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5617_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5618_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5619_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5620_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5621_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5622_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5623_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5624_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5625_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5626_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5627_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5628_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5629_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5630_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5631_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5632_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5633_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5634_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
# Downloaded 3dm_32_329_5635_1_nw.laz to /Volumes/SSD_portable/lidar_data/Split_NRW/zone_1.1/
