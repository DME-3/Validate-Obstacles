# %%
import json

# Load the provided JSON file
file_path = 'assets/index.json'

with open(file_path, 'r') as file:
    data = json.load(file)

total_files = 0
total_size = 0

for dataset in data.get('datasets', []):
    files = dataset.get('files', [])
    total_files += len(files)
    total_size += sum(int(file['size']) for file in files)

total_files, total_size
# Out:
# (35860, 3120908957711)

# %%
# Create a dictionary for quick lookup from the JSON data (much quicker than recursively looking up in the JSON)

def create_lookup_dict(json_data):

    lookup_dict = {}
    for dataset in json_data.get('datasets', []):
        for file in dataset.get('files', []):
            lookup_dict[file['name']] = (file['size'], file['timestamp'])
    return lookup_dict

# Create a lookup dictionary
lookup_dict = create_lookup_dict(data)

# %%
def parse_coordinates_from_filename(filename):
    """
    Extract easting and northing values from the file name.
    For example, from '3dm_32_280_5656_1_nw.laz', it will extract (32280, 5656).
    """
    parts = filename.split('_')
    easting = int(parts[1] + parts[2])
    northing = int(parts[3])
    return easting, northing

def calculate_zone_files_and_size(files, max_easting, max_northing):
    """
    Calculate the number of files and total size for each zone based on the given limits.
    """
    zones = {
        'zone_1': {'count': 0, 'size': 0},
        'zone_2': {'count': 0, 'size': 0},
        'zone_3': {'count': 0, 'size': 0},
        'zone_4': {'count': 0, 'size': 0}
    }

    for file in files:
        size = int(file['size'])
        easting, northing = parse_coordinates_from_filename(file['name'])

        if easting < max_easting and northing < max_northing:
            zones['zone_1']['count'] += 1
            zones['zone_1']['size'] += size
        elif easting < max_easting and northing >= max_northing:
            zones['zone_2']['count'] += 1
            zones['zone_2']['size'] += size
        elif easting >= max_easting and northing >= max_northing:
            zones['zone_3']['count'] += 1
            zones['zone_3']['size'] += size
        else: # easting >= max_easting and northing >= max_northing
            zones['zone_4']['count'] += 1
            zones['zone_4']['size'] += size

    return zones

def print_zone_results(zones):
    """
    Print the results for each zone.
    """
    for zone, data in zones.items():
        size_gb = data['size'] / (1024**3)  # Convert bytes to gigabytes
        print(f"{zone.upper()}: Number of files = {data['count']}, Total size = {size_gb:.2f} GB")

# %%
def calculate_size(filenames, lookup_dict = lookup_dict):
    total_files = 0
    total_size = 0

    for filename in filenames:
        file_info = lookup_dict.get(filename)
        if file_info:
            total_files += 1
            total_size += int(file_info[0])  # file_info[0] is the size

    return total_files, round(total_size / (1024**3), 2)  # Size in GB

# %%
def find_file_info(filename, json_data):
    """
    Search for a file in the JSON data and return its size and timestamp if found.
    If not found, return False.
    """
    for dataset in json_data.get('datasets', []):
        for file in dataset.get('files', []):
            if file['name'] == filename:
                return file['size'], file['timestamp']

    return False

# %%
# Find min max easting and northing for a list of names

def find_minmax_EN(filenames):

  min_easting, min_northing = parse_coordinates_from_filename(filenames[0])
  max_easting = min_easting
  max_northing = min_northing

  for file in filenames:

    easting, northing = parse_coordinates_from_filename(file)

    if easting < min_easting: min_easting = easting
    if northing < min_northing: min_northing = northing
    if easting > max_easting: max_easting = easting
    if northing > max_northing: max_northing = northing

  return min_easting, max_easting, min_northing, max_northing

#Segregate files into four zones based on the given limits and return their filenames.

def segregate_files_into_main_zones(files, max_easting, max_northing):
    """
    
    """

    zones = {
        'zone_1': [],
        'zone_2': [],
        'zone_3': [],
        'zone_4': []
    }

    for file in files:
        filename = file['name']
        easting, northing = parse_coordinates_from_filename(filename)

        if easting < max_easting and northing < max_northing:
            zones[list(zones.keys())[0]].append(filename)
        elif easting < max_easting and northing >= max_northing:
            zones[list(zones.keys())[1]].append(filename)
        elif easting >= max_easting and northing >= max_northing:
            zones[list(zones.keys())[2]].append(filename)
        else: # easting >= max_easting and northing >= max_northing
            zones[list(zones.keys())[3]].append(filename)

    return zones

def segregate_files_into_sub_zones(files, easting_range, northing_range, best_easting, best_northing, idx):
    """
    Segregate files into four subzones based on the given limits and return their filenames.
    """
    zones = {
          'zone_%s.1'%(idx): [],
          'zone_%s.2'%(idx): [],
          'zone_%s.3'%(idx): [],
          'zone_%s.4'%(idx): [],
      }

    for file in files:
        filename = file['name']
        easting, northing = parse_coordinates_from_filename(filename)

        if easting_range.start <= easting < best_easting and northing_range.start <= northing < best_northing:
            zones[list(zones.keys())[0]].append(filename)
        elif easting_range.start <= easting < best_easting and best_northing <= northing <= northing_range.stop :
            zones[list(zones.keys())[1]].append(filename)
        elif best_easting <= easting <= easting_range.stop and best_northing <= northing <= northing_range.stop:
            zones[list(zones.keys())[2]].append(filename)
        elif best_easting <= easting <= easting_range.stop and northing_range.start <= northing < best_northing:
            zones[list(zones.keys())[3]].append(filename)

    return zones

def write_zone_files(zones):
    """
    Write the filenames of each zone into separate text files.
    """
    for zone, filenames in zones.items():
        with open(f'{zone}_files.txt', 'w') as file:
            for filename in filenames:
                file.write(filename + '\n')

def calculate_zone_size(files, easting_start, easting_limit, northing_start, northing_limit):

  zone_size = 0

  for east in range(easting_start, easting_limit, 10):
    for north in range(northing_start, northing_limit, 10):

      tentative_filename = f'3dm_{str(east)[0:2]}_{str(east)[2:]}_{str(north)}_1_nw.laz'

      if tentative_filename in lookup_dict:

        size = int(lookup_dict[tentative_filename][0])

        zone_size += size

  return zone_size

def find_balanced_zones(files, easting_range, northing_range):
    best_balance = float('inf')
    best_easting = None
    best_northing = None

    for easting_limit in easting_range:
        for northing_limit in northing_range:

          tentative_zone_1 = calculate_zone_size(files, easting_range.start, easting_limit, northing_range.start, northing_limit)
          tentative_zone_2 = calculate_zone_size(files, easting_range.start, easting_limit, northing_limit, northing_range.stop)
          tentative_zone_3 = calculate_zone_size(files, easting_limit, easting_range.stop, northing_limit, northing_range.stop)
          tentative_zone_4 = calculate_zone_size(files, easting_limit, easting_range.stop, northing_range.start, northing_limit)

          sizes = [tentative_zone_1, tentative_zone_2, tentative_zone_3, tentative_zone_4]

          balance = max(sizes) - min(sizes)  # Example balance metric

          if balance < best_balance:
              best_balance = balance
              best_easting = easting_limit
              best_northing = northing_limit

    return best_easting, best_northing, best_balance

# %% [markdown]
# # Divide in zones and subzones

# %%
# Find the best division for the 4 main zones

min_easting, max_easting, min_northing, max_northing = find_minmax_EN(list(lookup_dict.keys()))

easting_range = range(min_easting, max_easting, 10) # step at 10 speeds up finding the best division
northing_range = range(min_northing, max_northing, 10)

print('Finding the 4 balanced main zones...')

all_files = []
for dataset in data.get('datasets', []):
    all_files.extend(dataset.get('files', []))

best_easting, best_northing, _ = find_balanced_zones(all_files, easting_range, northing_range)

print(f"Best balance at Easting: {best_easting}, Northing: {best_northing} for the 4 main zones")
print('\n')

# Create our 4 main zones

main_zones = segregate_files_into_main_zones(all_files, best_easting, best_northing)

idx = 1
sub_zones = []
number_of_files = 0
total_size = 0
coordinates = []

for zone in main_zones: # for each main zone

  # Find the best division in 4 subzones

  min_easting, max_easting, min_northing, max_northing = find_minmax_EN(main_zones[zone])

  easting_range = range(min_easting, max_easting, 10)
  northing_range = range(min_northing, max_northing, 10)

  print(f'Finding balanced subzones of main zone {idx}...')

  best_easting, best_northing, _ = find_balanced_zones(main_zones[zone], easting_range, northing_range)

  print(f'For main zone {zone}, the best balance is obtained for: Easting: {best_easting}, Northing: {best_northing}')

  # Create the subzones and write files

  sub_zones.append(segregate_files_into_sub_zones(all_files, easting_range, northing_range, best_easting, best_northing, idx))

  subtotal_number_of_files = 0
  subtotal_size = 0

  # List of coordinates for generating a KML or SHP
  coordinates.append((easting_range.start, best_easting, northing_range.start, best_northing)) # subzone x.1
  coordinates.append((easting_range.start, best_easting, best_northing, northing_range.stop)) # subzone x.2
  coordinates.append((best_easting, easting_range.stop, best_northing, northing_range.stop)) # subzone x.3
  coordinates.append((best_easting, easting_range.stop, northing_range.start, best_northing)) # subzone x.4

  for j in range(4): # For each of the 4 subzones

    files_number = len(list(sub_zones[idx-1].values())[j])
    sub_size = calculate_size(list(sub_zones[idx-1].values())[j])[1]

    subtotal_number_of_files += files_number
    subtotal_size += sub_size

    print(f'{str(files_number)} files in {list(sub_zones[idx-1].keys())[j]}, size = {str(sub_size)} GB')

  number_of_files += subtotal_number_of_files
  total_size += subtotal_size

  #write_zone_files(sub_zones[idx-1]) # uncomment to write new txt files

  idx += 1

  print('\n')

print('- Verification - ')
print('\n')
print(f'Total number of files after processing: {number_of_files}, cumulated size: {total_size}')
print(f'Comparison basis from original index file: {total_files}, {str(round(sum(int(file_info[0]) for file_info in lookup_dict.values()) / (1024**3), 2))} GB')
# Out:
# Finding the 4 balanced main zones...
# Best balance at Easting: 32400, Northing: 5686 for the 4 main zones
#
#
# Finding balanced subzones of main zone 1...
# For main zone zone_1, the best balance is obtained for: Easting: 32330, Northing: 5636
# 1692 files in zone_1.1, size = 287.82 GB
# 1996 files in zone_1.2, size = 140.43 GB
# 3500 files in zone_1.3, size = 327.18 GB
# 2416 files in zone_1.4, size = 272.47 GB
#
#
# Finding balanced subzones of main zone 2...
# For main zone zone_2, the best balance is obtained for: Easting: 32378, Northing: 5726
# 3012 files in zone_2.1, size = 194.44 GB
# 3396 files in zone_2.2, size = 140.96 GB
# 1572 files in zone_2.3, size = 69.91 GB
# 880 files in zone_2.4, size = 123.63 GB
#
#
# Finding balanced subzones of main zone 3...
# For main zone zone_3, the best balance is obtained for: Easting: 32470, Northing: 5726
# 2800 files in zone_3.1, size = 303.22 GB
# 4828 files in zone_3.2, size = 212.89 GB
# 3972 files in zone_3.3, size = 261.87 GB
# 1680 files in zone_3.4, size = 116.03 GB
#
#
# Finding balanced subzones of main zone 4...
# For main zone zone_4, the best balance is obtained for: Easting: 32430, Northing: 5674
# 1328 files in zone_4.1, size = 146.07 GB
# 360 files in zone_4.2, size = 68.33 GB
# 576 files in zone_4.3, size = 86.08 GB
# 1852 files in zone_4.4, size = 155.24 GB
#
#
# - Verification -
#
#
# Total number of files after processing: 35860, cumulated size: 2906.57
# Comparison basis from original index file: 35860, 2906.57 GB

# %%
sub_zones[1]['zone_2.3']
# Out:
# ['3dm_32_378_5726_1_nw.laz',
#  '3dm_32_378_5727_1_nw.laz',
#  '3dm_32_378_5728_1_nw.laz',
#  '3dm_32_378_5729_1_nw.laz',
#  '3dm_32_378_5730_1_nw.laz',
#  '3dm_32_378_5731_1_nw.laz',
#  '3dm_32_378_5732_1_nw.laz',
#  '3dm_32_378_5733_1_nw.laz',
#  '3dm_32_378_5734_1_nw.laz',
#  '3dm_32_378_5735_1_nw.laz',
#  '3dm_32_378_5736_1_nw.laz',
#  '3dm_32_378_5737_1_nw.laz',
#  '3dm_32_378_5738_1_nw.laz',
#  '3dm_32_378_5739_1_nw.laz',
#  '3dm_32_378_5740_1_nw.laz',
#  '3dm_32_378_5741_1_nw.laz',
#  '3dm_32_378_5742_1_nw.laz',
#  '3dm_32_378_5743_1_nw.laz',
#  '3dm_32_378_5744_1_nw.laz',
#  '3dm_32_378_5745_1_nw.laz',
#  '3dm_32_378_5746_1_nw.laz',
#  '3dm_32_378_5747_1_nw.laz',
#  '3dm_32_378_5748_1_nw.laz',
#  '3dm_32_378_5749_1_nw.laz',
#  '3dm_32_378_5750_1_nw.laz',
#  '3dm_32_378_5751_1_nw.laz',
#  '3dm_32_378_5752_1_nw.laz',
#  '3dm_32_378_5753_1_nw.laz',
#  '3dm_32_378_5754_1_nw.laz',
#  '3dm_32_378_5755_1_nw.laz',
#  '3dm_32_378_5756_1_nw.laz',
#  '3dm_32_378_5757_1_nw.laz',
#  '3dm_32_378_5758_1_nw.laz',
#  '3dm_32_378_5759_1_nw.laz',
#  '3dm_32_378_5760_1_nw.laz',
#  '3dm_32_378_5761_1_nw.laz',
#  '3dm_32_378_5762_1_nw.laz',
#  '3dm_32_378_5763_1_nw.laz',
#  '3dm_32_378_5764_1_nw.laz',
#  '3dm_32_378_5765_1_nw.laz',
#  '3dm_32_378_5766_1_nw.laz',
#  '3dm_32_378_5767_1_nw.laz',
#  '3dm_32_378_5768_1_nw.laz',
#  '3dm_32_378_5769_1_nw.laz',
#  '3dm_32_378_5770_1_nw.laz',
#  '3dm_32_378_5771_1_nw.laz',
#  '3dm_32_378_5772_1_nw.laz',
#  '3dm_32_378_5773_1_nw.laz',
#  '3dm_32_378_5774_1_nw.laz',
#  '3dm_32_378_5775_1_nw.laz',
#  '3dm_32_378_5776_1_nw.laz',
#  '3dm_32_378_5777_1_nw.laz',
#  '3dm_32_378_5778_1_nw.laz',
#  '3dm_32_378_5779_1_nw.laz',
#  '3dm_32_378_5780_1_nw.laz',
#  '3dm_32_378_5781_1_nw.laz',
#  '3dm_32_378_5782_1_nw.laz',
#  '3dm_32_378_5783_1_nw.laz',
#  '3dm_32_378_5784_1_nw.laz',
#  '3dm_32_378_5785_1_nw.laz',
#  '3dm_32_378_5786_1_nw.laz',
#  '3dm_32_378_5787_1_nw.laz',
#  '3dm_32_378_5788_1_nw.laz',
#  '3dm_32_378_5789_1_nw.laz',
#  '3dm_32_378_5790_1_nw.laz',
#  '3dm_32_378_5791_1_nw.laz',
#  '3dm_32_379_5726_1_nw.laz',
#  '3dm_32_379_5727_1_nw.laz',
#  '3dm_32_379_5728_1_nw.laz',
#  '3dm_32_379_5729_1_nw.laz',
#  '3dm_32_379_5730_1_nw.laz',
#  '3dm_32_379_5731_1_nw.laz',
#  '3dm_32_379_5732_1_nw.laz',
#  '3dm_32_379_5733_1_nw.laz',
#  '3dm_32_379_5734_1_nw.laz',
#  '3dm_32_379_5735_1_nw.laz',
#  '3dm_32_379_5736_1_nw.laz',
#  '3dm_32_379_5737_1_nw.laz',
#  '3dm_32_379_5738_1_nw.laz',
#  '3dm_32_379_5739_1_nw.laz',
#  '3dm_32_379_5740_1_nw.laz',
#  '3dm_32_379_5741_1_nw.laz',
#  '3dm_32_379_5742_1_nw.laz',
#  '3dm_32_379_5743_1_nw.laz',
#  '3dm_32_379_5744_1_nw.laz',
#  '3dm_32_379_5745_1_nw.laz',
#  '3dm_32_379_5746_1_nw.laz',
#  '3dm_32_379_5747_1_nw.laz',
#  '3dm_32_379_5748_1_nw.laz',
#  '3dm_32_379_5749_1_nw.laz',
#  '3dm_32_379_5750_1_nw.laz',
#  '3dm_32_379_5751_1_nw.laz',
#  '3dm_32_379_5752_1_nw.laz',
#  '3dm_32_379_5753_1_nw.laz',
#  '3dm_32_379_5754_1_nw.laz',
#  '3dm_32_379_5755_1_nw.laz',
#  '3dm_32_379_5756_1_nw.laz',
#  '3dm_32_379_5757_1_nw.laz',
#  '3dm_32_379_5758_1_nw.laz',
#  '3dm_32_379_5759_1_nw.laz',
#  '3dm_32_379_5760_1_nw.laz',
#  '3dm_32_379_5761_1_nw.laz',
#  '3dm_32_379_5762_1_nw.laz',
#  '3dm_32_379_5763_1_nw.laz',
#  '3dm_32_379_5764_1_nw.laz',
#  '3dm_32_379_5765_1_nw.laz',
#  '3dm_32_379_5766_1_nw.laz',
#  '3dm_32_379_5767_1_nw.laz',
#  '3dm_32_379_5768_1_nw.laz',
#  '3dm_32_379_5769_1_nw.laz',
#  '3dm_32_379_5770_1_nw.laz',
#  '3dm_32_379_5771_1_nw.laz',
#  '3dm_32_379_5772_1_nw.laz',
#  '3dm_32_379_5773_1_nw.laz',
#  '3dm_32_379_5774_1_nw.laz',
#  '3dm_32_379_5775_1_nw.laz',
#  '3dm_32_379_5776_1_nw.laz',
#  '3dm_32_379_5777_1_nw.laz',
#  '3dm_32_379_5778_1_nw.laz',
#  '3dm_32_379_5779_1_nw.laz',
#  '3dm_32_379_5780_1_nw.laz',
#  '3dm_32_379_5781_1_nw.laz',
#  '3dm_32_379_5782_1_nw.laz',
#  '3dm_32_379_5783_1_nw.laz',
#  '3dm_32_379_5784_1_nw.laz',
#  '3dm_32_379_5785_1_nw.laz',
#  '3dm_32_379_5786_1_nw.laz',
#  '3dm_32_379_5787_1_nw.laz',
#  '3dm_32_379_5788_1_nw.laz',
#  '3dm_32_379_5789_1_nw.laz',
#  '3dm_32_379_5790_1_nw.laz',
#  '3dm_32_379_5791_1_nw.laz',
#  '3dm_32_380_5726_1_nw.laz',
#  '3dm_32_380_5727_1_nw.laz',
#  '3dm_32_380_5728_1_nw.laz',
#  '3dm_32_380_5729_1_nw.laz',
#  '3dm_32_380_5730_1_nw.laz',
#  '3dm_32_380_5731_1_nw.laz',
#  '3dm_32_380_5732_1_nw.laz',
#  '3dm_32_380_5733_1_nw.laz',
#  '3dm_32_380_5734_1_nw.laz',
#  '3dm_32_380_5735_1_nw.laz',
#  '3dm_32_380_5736_1_nw.laz',
#  '3dm_32_380_5737_1_nw.laz',
#  '3dm_32_380_5738_1_nw.laz',
#  '3dm_32_380_5739_1_nw.laz',
#  '3dm_32_380_5740_1_nw.laz',
#  '3dm_32_380_5741_1_nw.laz',
#  '3dm_32_380_5742_1_nw.laz',
#  '3dm_32_380_5743_1_nw.laz',
#  '3dm_32_380_5744_1_nw.laz',
#  '3dm_32_380_5745_1_nw.laz',
#  '3dm_32_380_5746_1_nw.laz',
#  '3dm_32_380_5747_1_nw.laz',
#  '3dm_32_380_5748_1_nw.laz',
#  '3dm_32_380_5749_1_nw.laz',
#  '3dm_32_380_5750_1_nw.laz',
#  '3dm_32_380_5751_1_nw.laz',
#  '3dm_32_380_5752_1_nw.laz',
#  '3dm_32_380_5753_1_nw.laz',
#  '3dm_32_380_5754_1_nw.laz',
#  '3dm_32_380_5755_1_nw.laz',
#  '3dm_32_380_5756_1_nw.laz',
#  '3dm_32_380_5757_1_nw.laz',
#  '3dm_32_380_5758_1_nw.laz',
#  '3dm_32_380_5759_1_nw.laz',
#  '3dm_32_380_5760_1_nw.laz',
#  '3dm_32_380_5761_1_nw.laz',
#  '3dm_32_380_5762_1_nw.laz',
#  '3dm_32_380_5763_1_nw.laz',
#  '3dm_32_380_5764_1_nw.laz',
#  '3dm_32_380_5765_1_nw.laz',
#  '3dm_32_380_5766_1_nw.laz',
#  '3dm_32_380_5767_1_nw.laz',
#  '3dm_32_380_5768_1_nw.laz',
#  '3dm_32_380_5769_1_nw.laz',
#  '3dm_32_380_5770_1_nw.laz',
#  '3dm_32_380_5771_1_nw.laz',
#  '3dm_32_380_5772_1_nw.laz',
#  '3dm_32_380_5773_1_nw.laz',
#  '3dm_32_380_5774_1_nw.laz',
#  '3dm_32_380_5775_1_nw.laz',
#  '3dm_32_380_5776_1_nw.laz',
#  '3dm_32_380_5777_1_nw.laz',
#  '3dm_32_380_5778_1_nw.laz',
#  '3dm_32_380_5779_1_nw.laz',
#  '3dm_32_380_5780_1_nw.laz',
#  '3dm_32_380_5781_1_nw.laz',
#  '3dm_32_380_5782_1_nw.laz',
#  '3dm_32_380_5783_1_nw.laz',
#  '3dm_32_380_5784_1_nw.laz',
#  '3dm_32_380_5785_1_nw.laz',
#  '3dm_32_380_5786_1_nw.laz',
#  '3dm_32_380_5787_1_nw.laz',
#  '3dm_32_380_5788_1_nw.laz',
#  '3dm_32_380_5789_1_nw.laz',
#  '3dm_32_380_5790_1_nw.laz',
#  '3dm_32_380_5791_1_nw.laz',
#  '3dm_32_381_5726_1_nw.laz',
#  '3dm_32_381_5727_1_nw.laz',
#  '3dm_32_381_5728_1_nw.laz',
#  '3dm_32_381_5729_1_nw.laz',
#  '3dm_32_381_5730_1_nw.laz',
#  '3dm_32_381_5731_1_nw.laz',
#  '3dm_32_381_5732_1_nw.laz',
#  '3dm_32_381_5733_1_nw.laz',
#  '3dm_32_381_5734_1_nw.laz',
#  '3dm_32_381_5735_1_nw.laz',
#  '3dm_32_381_5736_1_nw.laz',
#  '3dm_32_381_5737_1_nw.laz',
#  '3dm_32_381_5738_1_nw.laz',
#  '3dm_32_381_5739_1_nw.laz',
#  '3dm_32_381_5740_1_nw.laz',
#  '3dm_32_381_5741_1_nw.laz',
#  '3dm_32_381_5742_1_nw.laz',
#  '3dm_32_381_5743_1_nw.laz',
#  '3dm_32_381_5744_1_nw.laz',
#  '3dm_32_381_5745_1_nw.laz',
#  '3dm_32_381_5746_1_nw.laz',
#  '3dm_32_381_5747_1_nw.laz',
#  '3dm_32_381_5748_1_nw.laz',
#  '3dm_32_381_5749_1_nw.laz',
#  '3dm_32_381_5750_1_nw.laz',
#  '3dm_32_381_5751_1_nw.laz',
#  '3dm_32_381_5752_1_nw.laz',
#  '3dm_32_381_5753_1_nw.laz',
#  '3dm_32_381_5754_1_nw.laz',
#  '3dm_32_381_5755_1_nw.laz',
#  '3dm_32_381_5756_1_nw.laz',
#  '3dm_32_381_5757_1_nw.laz',
#  '3dm_32_381_5758_1_nw.laz',
#  '3dm_32_381_5759_1_nw.laz',
#  '3dm_32_381_5760_1_nw.laz',
#  '3dm_32_381_5761_1_nw.laz',
#  '3dm_32_381_5762_1_nw.laz',
#  '3dm_32_381_5763_1_nw.laz',
#  '3dm_32_381_5764_1_nw.laz',
#  '3dm_32_381_5765_1_nw.laz',
#  '3dm_32_381_5766_1_nw.laz',
#  '3dm_32_381_5767_1_nw.laz',
#  '3dm_32_381_5768_1_nw.laz',
#  '3dm_32_381_5769_1_nw.laz',
#  '3dm_32_381_5770_1_nw.laz',
#  '3dm_32_381_5771_1_nw.laz',
#  '3dm_32_381_5772_1_nw.laz',
#  '3dm_32_381_5773_1_nw.laz',
#  '3dm_32_381_5774_1_nw.laz',
#  '3dm_32_381_5775_1_nw.laz',
#  '3dm_32_381_5776_1_nw.laz',
#  '3dm_32_381_5777_1_nw.laz',
#  '3dm_32_381_5778_1_nw.laz',
#  '3dm_32_381_5779_1_nw.laz',
#  '3dm_32_381_5780_1_nw.laz',
#  '3dm_32_381_5781_1_nw.laz',
#  '3dm_32_381_5782_1_nw.laz',
#  '3dm_32_381_5783_1_nw.laz',
#  '3dm_32_381_5784_1_nw.laz',
#  '3dm_32_381_5785_1_nw.laz',
#  '3dm_32_381_5786_1_nw.laz',
#  '3dm_32_381_5787_1_nw.laz',
#  '3dm_32_381_5788_1_nw.laz',
#  '3dm_32_381_5789_1_nw.laz',
#  '3dm_32_381_5790_1_nw.laz',
#  '3dm_32_381_5791_1_nw.laz',
#  '3dm_32_382_5726_1_nw.laz',
#  '3dm_32_382_5727_1_nw.laz',
#  '3dm_32_382_5728_1_nw.laz',
#  '3dm_32_382_5729_1_nw.laz',
#  '3dm_32_382_5730_1_nw.laz',
#  '3dm_32_382_5731_1_nw.laz',
#  '3dm_32_382_5732_1_nw.laz',
#  '3dm_32_382_5733_1_nw.laz',
#  '3dm_32_382_5734_1_nw.laz',
#  '3dm_32_382_5735_1_nw.laz',
#  '3dm_32_382_5736_1_nw.laz',
#  '3dm_32_382_5737_1_nw.laz',
#  '3dm_32_382_5738_1_nw.laz',
#  '3dm_32_382_5739_1_nw.laz',
#  '3dm_32_382_5740_1_nw.laz',
#  '3dm_32_382_5741_1_nw.laz',
#  '3dm_32_382_5742_1_nw.laz',
#  '3dm_32_382_5743_1_nw.laz',
#  '3dm_32_382_5744_1_nw.laz',
#  '3dm_32_382_5745_1_nw.laz',
#  '3dm_32_382_5746_1_nw.laz',
#  '3dm_32_382_5747_1_nw.laz',
#  '3dm_32_382_5748_1_nw.laz',
#  '3dm_32_382_5749_1_nw.laz',
#  '3dm_32_382_5750_1_nw.laz',
#  '3dm_32_382_5751_1_nw.laz',
#  '3dm_32_382_5752_1_nw.laz',
#  '3dm_32_382_5753_1_nw.laz',
#  '3dm_32_382_5754_1_nw.laz',
#  '3dm_32_382_5755_1_nw.laz',
#  '3dm_32_382_5756_1_nw.laz',
#  '3dm_32_382_5757_1_nw.laz',
#  '3dm_32_382_5758_1_nw.laz',
#  '3dm_32_382_5759_1_nw.laz',
#  '3dm_32_382_5760_1_nw.laz',
#  '3dm_32_382_5761_1_nw.laz',
#  '3dm_32_382_5762_1_nw.laz',
#  '3dm_32_382_5763_1_nw.laz',
#  '3dm_32_382_5764_1_nw.laz',
#  '3dm_32_382_5765_1_nw.laz',
#  '3dm_32_382_5766_1_nw.laz',
#  '3dm_32_382_5767_1_nw.laz',
#  '3dm_32_382_5768_1_nw.laz',
#  '3dm_32_382_5769_1_nw.laz',
#  '3dm_32_382_5770_1_nw.laz',
#  '3dm_32_382_5771_1_nw.laz',
#  '3dm_32_382_5772_1_nw.laz',
#  '3dm_32_382_5773_1_nw.laz',
#  '3dm_32_382_5774_1_nw.laz',
#  '3dm_32_382_5775_1_nw.laz',
#  '3dm_32_382_5776_1_nw.laz',
#  '3dm_32_382_5777_1_nw.laz',
#  '3dm_32_382_5778_1_nw.laz',
#  '3dm_32_382_5779_1_nw.laz',
#  '3dm_32_382_5780_1_nw.laz',
#  '3dm_32_382_5781_1_nw.laz',
#  '3dm_32_382_5782_1_nw.laz',
#  '3dm_32_382_5783_1_nw.laz',
#  '3dm_32_382_5784_1_nw.laz',
#  '3dm_32_382_5785_1_nw.laz',
#  '3dm_32_382_5786_1_nw.laz',
#  '3dm_32_382_5787_1_nw.laz',
#  '3dm_32_382_5788_1_nw.laz',
#  '3dm_32_382_5789_1_nw.laz',
#  '3dm_32_382_5790_1_nw.laz',
#  '3dm_32_382_5791_1_nw.laz',
#  '3dm_32_383_5726_1_nw.laz',
#  '3dm_32_383_5727_1_nw.laz',
#  '3dm_32_383_5728_1_nw.laz',
#  '3dm_32_383_5729_1_nw.laz',
#  '3dm_32_383_5730_1_nw.laz',
#  '3dm_32_383_5731_1_nw.laz',
#  '3dm_32_383_5732_1_nw.laz',
#  '3dm_32_383_5733_1_nw.laz',
#  '3dm_32_383_5734_1_nw.laz',
#  '3dm_32_383_5735_1_nw.laz',
#  '3dm_32_383_5736_1_nw.laz',
#  '3dm_32_383_5737_1_nw.laz',
#  '3dm_32_383_5738_1_nw.laz',
#  '3dm_32_383_5739_1_nw.laz',
#  '3dm_32_383_5740_1_nw.laz',
#  '3dm_32_383_5741_1_nw.laz',
#  '3dm_32_383_5742_1_nw.laz',
#  '3dm_32_383_5743_1_nw.laz',
#  '3dm_32_383_5744_1_nw.laz',
#  '3dm_32_383_5745_1_nw.laz',
#  '3dm_32_383_5746_1_nw.laz',
#  '3dm_32_383_5747_1_nw.laz',
#  '3dm_32_383_5748_1_nw.laz',
#  '3dm_32_383_5749_1_nw.laz',
#  '3dm_32_383_5750_1_nw.laz',
#  '3dm_32_383_5751_1_nw.laz',
#  '3dm_32_383_5752_1_nw.laz',
#  '3dm_32_383_5753_1_nw.laz',
#  '3dm_32_383_5754_1_nw.laz',
#  '3dm_32_383_5755_1_nw.laz',
#  '3dm_32_383_5756_1_nw.laz',
#  '3dm_32_383_5757_1_nw.laz',
#  '3dm_32_383_5758_1_nw.laz',
#  '3dm_32_383_5759_1_nw.laz',
#  '3dm_32_383_5760_1_nw.laz',
#  '3dm_32_383_5761_1_nw.laz',
#  '3dm_32_383_5762_1_nw.laz',
#  '3dm_32_383_5763_1_nw.laz',
#  '3dm_32_383_5764_1_nw.laz',
#  '3dm_32_383_5765_1_nw.laz',
#  '3dm_32_383_5766_1_nw.laz',
#  '3dm_32_383_5767_1_nw.laz',
#  '3dm_32_383_5768_1_nw.laz',
#  '3dm_32_383_5769_1_nw.laz',
#  '3dm_32_383_5770_1_nw.laz',
#  '3dm_32_383_5771_1_nw.laz',
#  '3dm_32_383_5772_1_nw.laz',
#  '3dm_32_383_5773_1_nw.laz',
#  '3dm_32_383_5774_1_nw.laz',
#  '3dm_32_383_5775_1_nw.laz',
#  '3dm_32_383_5776_1_nw.laz',
#  '3dm_32_383_5777_1_nw.laz',
#  '3dm_32_383_5778_1_nw.laz',
#  '3dm_32_383_5779_1_nw.laz',
#  '3dm_32_383_5780_1_nw.laz',
#  '3dm_32_383_5781_1_nw.laz',
#  '3dm_32_383_5782_1_nw.laz',
#  '3dm_32_383_5783_1_nw.laz',
#  '3dm_32_383_5784_1_nw.laz',
#  '3dm_32_383_5785_1_nw.laz',
#  '3dm_32_383_5786_1_nw.laz',
#  '3dm_32_383_5787_1_nw.laz',
#  '3dm_32_383_5788_1_nw.laz',
#  '3dm_32_383_5789_1_nw.laz',
#  '3dm_32_383_5790_1_nw.laz',
#  '3dm_32_383_5791_1_nw.laz',
#  '3dm_32_384_5726_1_nw.laz',
#  '3dm_32_384_5727_1_nw.laz',
#  '3dm_32_384_5728_1_nw.laz',
#  '3dm_32_384_5729_1_nw.laz',
#  '3dm_32_384_5730_1_nw.laz',
#  '3dm_32_384_5731_1_nw.laz',
#  '3dm_32_384_5732_1_nw.laz',
#  '3dm_32_384_5733_1_nw.laz',
#  '3dm_32_384_5734_1_nw.laz',
#  '3dm_32_384_5735_1_nw.laz',
#  '3dm_32_384_5736_1_nw.laz',
#  '3dm_32_384_5737_1_nw.laz',
#  '3dm_32_384_5738_1_nw.laz',
#  '3dm_32_384_5739_1_nw.laz',
#  '3dm_32_384_5740_1_nw.laz',
#  '3dm_32_384_5741_1_nw.laz',
#  '3dm_32_384_5742_1_nw.laz',
#  '3dm_32_384_5743_1_nw.laz',
#  '3dm_32_384_5744_1_nw.laz',
#  '3dm_32_384_5745_1_nw.laz',
#  '3dm_32_384_5746_1_nw.laz',
#  '3dm_32_384_5747_1_nw.laz',
#  '3dm_32_384_5748_1_nw.laz',
#  '3dm_32_384_5749_1_nw.laz',
#  '3dm_32_384_5750_1_nw.laz',
#  '3dm_32_384_5751_1_nw.laz',
#  '3dm_32_384_5752_1_nw.laz',
#  '3dm_32_384_5753_1_nw.laz',
#  '3dm_32_384_5754_1_nw.laz',
#  '3dm_32_384_5755_1_nw.laz',
#  '3dm_32_384_5756_1_nw.laz',
#  '3dm_32_384_5757_1_nw.laz',
#  '3dm_32_384_5758_1_nw.laz',
#  '3dm_32_384_5759_1_nw.laz',
#  '3dm_32_384_5760_1_nw.laz',
#  '3dm_32_384_5761_1_nw.laz',
#  '3dm_32_384_5762_1_nw.laz',
#  '3dm_32_384_5763_1_nw.laz',
#  '3dm_32_384_5764_1_nw.laz',
#  '3dm_32_384_5765_1_nw.laz',
#  '3dm_32_384_5766_1_nw.laz',
#  '3dm_32_384_5767_1_nw.laz',
#  '3dm_32_384_5768_1_nw.laz',
#  '3dm_32_384_5769_1_nw.laz',
#  '3dm_32_384_5770_1_nw.laz',
#  '3dm_32_384_5771_1_nw.laz',
#  '3dm_32_384_5772_1_nw.laz',
#  '3dm_32_384_5773_1_nw.laz',
#  '3dm_32_384_5774_1_nw.laz',
#  '3dm_32_384_5775_1_nw.laz',
#  '3dm_32_384_5776_1_nw.laz',
#  '3dm_32_384_5777_1_nw.laz',
#  '3dm_32_384_5778_1_nw.laz',
#  '3dm_32_384_5779_1_nw.laz',
#  '3dm_32_384_5780_1_nw.laz',
#  '3dm_32_384_5781_1_nw.laz',
#  '3dm_32_384_5782_1_nw.laz',
#  '3dm_32_384_5783_1_nw.laz',
#  '3dm_32_384_5784_1_nw.laz',
#  '3dm_32_384_5785_1_nw.laz',
#  '3dm_32_384_5786_1_nw.laz',
#  '3dm_32_384_5787_1_nw.laz',
#  '3dm_32_384_5788_1_nw.laz',
#  '3dm_32_384_5789_1_nw.laz',
#  '3dm_32_384_5790_1_nw.laz',
#  '3dm_32_384_5791_1_nw.laz',
#  '3dm_32_384_5792_1_nw.laz',
#  '3dm_32_384_5793_1_nw.laz',
#  '3dm_32_385_5726_1_nw.laz',
#  '3dm_32_385_5727_1_nw.laz',
#  '3dm_32_385_5728_1_nw.laz',
#  '3dm_32_385_5729_1_nw.laz',
#  '3dm_32_385_5730_1_nw.laz',
#  '3dm_32_385_5731_1_nw.laz',
#  '3dm_32_385_5732_1_nw.laz',
#  '3dm_32_385_5733_1_nw.laz',
#  '3dm_32_385_5734_1_nw.laz',
#  '3dm_32_385_5735_1_nw.laz',
#  '3dm_32_385_5736_1_nw.laz',
#  '3dm_32_385_5737_1_nw.laz',
#  '3dm_32_385_5738_1_nw.laz',
#  '3dm_32_385_5739_1_nw.laz',
#  '3dm_32_385_5740_1_nw.laz',
#  '3dm_32_385_5741_1_nw.laz',
#  '3dm_32_385_5742_1_nw.laz',
#  '3dm_32_385_5743_1_nw.laz',
#  '3dm_32_385_5744_1_nw.laz',
#  '3dm_32_385_5745_1_nw.laz',
#  '3dm_32_385_5746_1_nw.laz',
#  '3dm_32_385_5747_1_nw.laz',
#  '3dm_32_385_5748_1_nw.laz',
#  '3dm_32_385_5749_1_nw.laz',
#  '3dm_32_385_5750_1_nw.laz',
#  '3dm_32_385_5751_1_nw.laz',
#  '3dm_32_385_5752_1_nw.laz',
#  '3dm_32_385_5753_1_nw.laz',
#  '3dm_32_385_5754_1_nw.laz',
#  '3dm_32_385_5755_1_nw.laz',
#  '3dm_32_385_5756_1_nw.laz',
#  '3dm_32_385_5757_1_nw.laz',
#  '3dm_32_385_5758_1_nw.laz',
#  '3dm_32_385_5759_1_nw.laz',
#  '3dm_32_385_5760_1_nw.laz',
#  '3dm_32_385_5761_1_nw.laz',
#  '3dm_32_385_5762_1_nw.laz',
#  '3dm_32_385_5763_1_nw.laz',
#  '3dm_32_385_5764_1_nw.laz',
#  '3dm_32_385_5765_1_nw.laz',
#  '3dm_32_385_5766_1_nw.laz',
#  '3dm_32_385_5767_1_nw.laz',
#  '3dm_32_385_5768_1_nw.laz',
#  '3dm_32_385_5769_1_nw.laz',
#  '3dm_32_385_5770_1_nw.laz',
#  '3dm_32_385_5771_1_nw.laz',
#  '3dm_32_385_5772_1_nw.laz',
#  '3dm_32_385_5773_1_nw.laz',
#  '3dm_32_385_5774_1_nw.laz',
#  '3dm_32_385_5775_1_nw.laz',
#  '3dm_32_385_5776_1_nw.laz',
#  '3dm_32_385_5777_1_nw.laz',
#  '3dm_32_385_5778_1_nw.laz',
#  '3dm_32_385_5779_1_nw.laz',
#  '3dm_32_385_5780_1_nw.laz',
#  '3dm_32_385_5781_1_nw.laz',
#  '3dm_32_385_5782_1_nw.laz',
#  '3dm_32_385_5783_1_nw.laz',
#  '3dm_32_385_5784_1_nw.laz',
#  '3dm_32_385_5785_1_nw.laz',
#  '3dm_32_385_5786_1_nw.laz',
#  '3dm_32_385_5787_1_nw.laz',
#  '3dm_32_385_5788_1_nw.laz',
#  '3dm_32_385_5789_1_nw.laz',
#  '3dm_32_385_5790_1_nw.laz',
#  '3dm_32_385_5791_1_nw.laz',
#  '3dm_32_385_5792_1_nw.laz',
#  '3dm_32_385_5793_1_nw.laz',
#  '3dm_32_386_5726_1_nw.laz',
#  '3dm_32_386_5727_1_nw.laz',
#  '3dm_32_386_5728_1_nw.laz',
#  '3dm_32_386_5729_1_nw.laz',
#  '3dm_32_386_5730_1_nw.laz',
#  '3dm_32_386_5731_1_nw.laz',
#  '3dm_32_386_5732_1_nw.laz',
#  '3dm_32_386_5733_1_nw.laz',
#  '3dm_32_386_5734_1_nw.laz',
#  '3dm_32_386_5735_1_nw.laz',
#  '3dm_32_386_5736_1_nw.laz',
#  '3dm_32_386_5737_1_nw.laz',
#  '3dm_32_386_5738_1_nw.laz',
#  '3dm_32_386_5739_1_nw.laz',
#  '3dm_32_386_5740_1_nw.laz',
#  '3dm_32_386_5741_1_nw.laz',
#  '3dm_32_386_5742_1_nw.laz',
#  '3dm_32_386_5743_1_nw.laz',
#  '3dm_32_386_5744_1_nw.laz',
#  '3dm_32_386_5745_1_nw.laz',
#  '3dm_32_386_5746_1_nw.laz',
#  '3dm_32_386_5747_1_nw.laz',
#  '3dm_32_386_5748_1_nw.laz',
#  '3dm_32_386_5749_1_nw.laz',
#  '3dm_32_386_5750_1_nw.laz',
#  '3dm_32_386_5751_1_nw.laz',
#  '3dm_32_386_5752_1_nw.laz',
#  '3dm_32_386_5753_1_nw.laz',
#  '3dm_32_386_5754_1_nw.laz',
#  '3dm_32_386_5755_1_nw.laz',
#  '3dm_32_386_5756_1_nw.laz',
#  '3dm_32_386_5757_1_nw.laz',
#  '3dm_32_386_5758_1_nw.laz',
#  '3dm_32_386_5759_1_nw.laz',
#  '3dm_32_386_5760_1_nw.laz',
#  '3dm_32_386_5761_1_nw.laz',
#  '3dm_32_386_5762_1_nw.laz',
#  '3dm_32_386_5763_1_nw.laz',
#  '3dm_32_386_5764_1_nw.laz',
#  '3dm_32_386_5765_1_nw.laz',
#  '3dm_32_386_5766_1_nw.laz',
#  '3dm_32_386_5767_1_nw.laz',
#  '3dm_32_386_5768_1_nw.laz',
#  '3dm_32_386_5769_1_nw.laz',
#  '3dm_32_386_5770_1_nw.laz',
#  '3dm_32_386_5771_1_nw.laz',
#  '3dm_32_386_5772_1_nw.laz',
#  '3dm_32_386_5773_1_nw.laz',
#  '3dm_32_386_5774_1_nw.laz',
#  '3dm_32_386_5775_1_nw.laz',
#  '3dm_32_386_5776_1_nw.laz',
#  '3dm_32_386_5777_1_nw.laz',
#  '3dm_32_386_5778_1_nw.laz',
#  '3dm_32_386_5779_1_nw.laz',
#  '3dm_32_386_5780_1_nw.laz',
#  '3dm_32_386_5781_1_nw.laz',
#  '3dm_32_386_5782_1_nw.laz',
#  '3dm_32_386_5783_1_nw.laz',
#  '3dm_32_386_5784_1_nw.laz',
#  '3dm_32_386_5785_1_nw.laz',
#  '3dm_32_386_5786_1_nw.laz',
#  '3dm_32_386_5787_1_nw.laz',
#  '3dm_32_386_5788_1_nw.laz',
#  '3dm_32_386_5789_1_nw.laz',
#  '3dm_32_386_5790_1_nw.laz',
#  '3dm_32_386_5791_1_nw.laz',
#  '3dm_32_386_5792_1_nw.laz',
#  '3dm_32_386_5793_1_nw.laz',
#  '3dm_32_386_5794_1_nw.laz',
#  '3dm_32_386_5795_1_nw.laz',
#  '3dm_32_387_5726_1_nw.laz',
#  '3dm_32_387_5727_1_nw.laz',
#  '3dm_32_387_5728_1_nw.laz',
#  '3dm_32_387_5729_1_nw.laz',
#  '3dm_32_387_5730_1_nw.laz',
#  '3dm_32_387_5731_1_nw.laz',
#  '3dm_32_387_5732_1_nw.laz',
#  '3dm_32_387_5733_1_nw.laz',
#  '3dm_32_387_5734_1_nw.laz',
#  '3dm_32_387_5735_1_nw.laz',
#  '3dm_32_387_5736_1_nw.laz',
#  '3dm_32_387_5737_1_nw.laz',
#  '3dm_32_387_5738_1_nw.laz',
#  '3dm_32_387_5739_1_nw.laz',
#  '3dm_32_387_5740_1_nw.laz',
#  '3dm_32_387_5741_1_nw.laz',
#  '3dm_32_387_5742_1_nw.laz',
#  '3dm_32_387_5743_1_nw.laz',
#  '3dm_32_387_5744_1_nw.laz',
#  '3dm_32_387_5745_1_nw.laz',
#  '3dm_32_387_5746_1_nw.laz',
#  '3dm_32_387_5747_1_nw.laz',
#  '3dm_32_387_5748_1_nw.laz',
#  '3dm_32_387_5749_1_nw.laz',
#  '3dm_32_387_5750_1_nw.laz',
#  '3dm_32_387_5751_1_nw.laz',
#  '3dm_32_387_5752_1_nw.laz',
#  '3dm_32_387_5753_1_nw.laz',
#  '3dm_32_387_5754_1_nw.laz',
#  '3dm_32_387_5755_1_nw.laz',
#  '3dm_32_387_5756_1_nw.laz',
#  '3dm_32_387_5757_1_nw.laz',
#  '3dm_32_387_5758_1_nw.laz',
#  '3dm_32_387_5759_1_nw.laz',
#  '3dm_32_387_5760_1_nw.laz',
#  '3dm_32_387_5761_1_nw.laz',
#  '3dm_32_387_5762_1_nw.laz',
#  '3dm_32_387_5763_1_nw.laz',
#  '3dm_32_387_5764_1_nw.laz',
#  '3dm_32_387_5765_1_nw.laz',
#  '3dm_32_387_5766_1_nw.laz',
#  '3dm_32_387_5767_1_nw.laz',
#  '3dm_32_387_5768_1_nw.laz',
#  '3dm_32_387_5769_1_nw.laz',
#  '3dm_32_387_5770_1_nw.laz',
#  '3dm_32_387_5771_1_nw.laz',
#  '3dm_32_387_5772_1_nw.laz',
#  '3dm_32_387_5773_1_nw.laz',
#  '3dm_32_387_5774_1_nw.laz',
#  '3dm_32_387_5775_1_nw.laz',
#  '3dm_32_387_5776_1_nw.laz',
#  '3dm_32_387_5777_1_nw.laz',
#  '3dm_32_387_5778_1_nw.laz',
#  '3dm_32_387_5779_1_nw.laz',
#  '3dm_32_387_5780_1_nw.laz',
#  '3dm_32_387_5781_1_nw.laz',
#  '3dm_32_387_5782_1_nw.laz',
#  '3dm_32_387_5783_1_nw.laz',
#  '3dm_32_387_5784_1_nw.laz',
#  '3dm_32_387_5785_1_nw.laz',
#  '3dm_32_387_5786_1_nw.laz',
#  '3dm_32_387_5787_1_nw.laz',
#  '3dm_32_387_5788_1_nw.laz',
#  '3dm_32_387_5789_1_nw.laz',
#  '3dm_32_387_5790_1_nw.laz',
#  '3dm_32_387_5791_1_nw.laz',
#  '3dm_32_387_5792_1_nw.laz',
#  '3dm_32_387_5793_1_nw.laz',
#  '3dm_32_387_5794_1_nw.laz',
#  '3dm_32_387_5795_1_nw.laz',
#  '3dm_32_388_5726_1_nw.laz',
#  '3dm_32_388_5727_1_nw.laz',
#  '3dm_32_388_5728_1_nw.laz',
#  '3dm_32_388_5729_1_nw.laz',
#  '3dm_32_388_5730_1_nw.laz',
#  '3dm_32_388_5731_1_nw.laz',
#  '3dm_32_388_5732_1_nw.laz',
#  '3dm_32_388_5733_1_nw.laz',
#  '3dm_32_388_5734_1_nw.laz',
#  '3dm_32_388_5735_1_nw.laz',
#  '3dm_32_388_5736_1_nw.laz',
#  '3dm_32_388_5737_1_nw.laz',
#  '3dm_32_388_5738_1_nw.laz',
#  '3dm_32_388_5739_1_nw.laz',
#  '3dm_32_388_5740_1_nw.laz',
#  '3dm_32_388_5741_1_nw.laz',
#  '3dm_32_388_5742_1_nw.laz',
#  '3dm_32_388_5743_1_nw.laz',
#  '3dm_32_388_5744_1_nw.laz',
#  '3dm_32_388_5745_1_nw.laz',
#  '3dm_32_388_5746_1_nw.laz',
#  '3dm_32_388_5747_1_nw.laz',
#  '3dm_32_388_5748_1_nw.laz',
#  '3dm_32_388_5749_1_nw.laz',
#  '3dm_32_388_5750_1_nw.laz',
#  '3dm_32_388_5751_1_nw.laz',
#  '3dm_32_388_5752_1_nw.laz',
#  '3dm_32_388_5753_1_nw.laz',
#  '3dm_32_388_5754_1_nw.laz',
#  '3dm_32_388_5755_1_nw.laz',
#  '3dm_32_388_5756_1_nw.laz',
#  '3dm_32_388_5757_1_nw.laz',
#  '3dm_32_388_5758_1_nw.laz',
#  '3dm_32_388_5759_1_nw.laz',
#  '3dm_32_388_5760_1_nw.laz',
#  '3dm_32_388_5761_1_nw.laz',
#  '3dm_32_388_5762_1_nw.laz',
#  '3dm_32_388_5763_1_nw.laz',
#  '3dm_32_388_5764_1_nw.laz',
#  '3dm_32_388_5765_1_nw.laz',
#  '3dm_32_388_5766_1_nw.laz',
#  '3dm_32_388_5767_1_nw.laz',
#  '3dm_32_388_5768_1_nw.laz',
#  '3dm_32_388_5769_1_nw.laz',
#  '3dm_32_388_5770_1_nw.laz',
#  '3dm_32_388_5771_1_nw.laz',
#  '3dm_32_388_5772_1_nw.laz',
#  '3dm_32_388_5773_1_nw.laz',
#  '3dm_32_388_5774_1_nw.laz',
#  '3dm_32_388_5775_1_nw.laz',
#  '3dm_32_388_5776_1_nw.laz',
#  '3dm_32_388_5777_1_nw.laz',
#  '3dm_32_388_5778_1_nw.laz',
#  '3dm_32_388_5779_1_nw.laz',
#  '3dm_32_388_5780_1_nw.laz',
#  '3dm_32_388_5781_1_nw.laz',
#  '3dm_32_388_5782_1_nw.laz',
#  '3dm_32_388_5783_1_nw.laz',
#  '3dm_32_388_5784_1_nw.laz',
#  '3dm_32_388_5785_1_nw.laz',
#  '3dm_32_388_5786_1_nw.laz',
#  '3dm_32_388_5787_1_nw.laz',
#  '3dm_32_388_5788_1_nw.laz',
#  '3dm_32_388_5789_1_nw.laz',
#  '3dm_32_388_5790_1_nw.laz',
#  '3dm_32_388_5791_1_nw.laz',
#  '3dm_32_388_5792_1_nw.laz',
#  '3dm_32_388_5793_1_nw.laz',
#  '3dm_32_388_5794_1_nw.laz',
#  '3dm_32_388_5795_1_nw.laz',
#  '3dm_32_388_5796_1_nw.laz',
#  '3dm_32_388_5797_1_nw.laz',
#  '3dm_32_389_5726_1_nw.laz',
#  '3dm_32_389_5727_1_nw.laz',
#  '3dm_32_389_5728_1_nw.laz',
#  '3dm_32_389_5729_1_nw.laz',
#  '3dm_32_389_5730_1_nw.laz',
#  '3dm_32_389_5731_1_nw.laz',
#  '3dm_32_389_5732_1_nw.laz',
#  '3dm_32_389_5733_1_nw.laz',
#  '3dm_32_389_5734_1_nw.laz',
#  '3dm_32_389_5735_1_nw.laz',
#  '3dm_32_389_5736_1_nw.laz',
#  '3dm_32_389_5737_1_nw.laz',
#  '3dm_32_389_5738_1_nw.laz',
#  '3dm_32_389_5739_1_nw.laz',
#  '3dm_32_389_5740_1_nw.laz',
#  '3dm_32_389_5741_1_nw.laz',
#  '3dm_32_389_5742_1_nw.laz',
#  '3dm_32_389_5743_1_nw.laz',
#  '3dm_32_389_5744_1_nw.laz',
#  '3dm_32_389_5745_1_nw.laz',
#  '3dm_32_389_5746_1_nw.laz',
#  '3dm_32_389_5747_1_nw.laz',
#  '3dm_32_389_5748_1_nw.laz',
#  '3dm_32_389_5749_1_nw.laz',
#  '3dm_32_389_5750_1_nw.laz',
#  '3dm_32_389_5751_1_nw.laz',
#  '3dm_32_389_5752_1_nw.laz',
#  '3dm_32_389_5753_1_nw.laz',
#  '3dm_32_389_5754_1_nw.laz',
#  '3dm_32_389_5755_1_nw.laz',
#  '3dm_32_389_5756_1_nw.laz',
#  '3dm_32_389_5757_1_nw.laz',
#  '3dm_32_389_5758_1_nw.laz',
#  '3dm_32_389_5759_1_nw.laz',
#  '3dm_32_389_5760_1_nw.laz',
#  '3dm_32_389_5761_1_nw.laz',
#  '3dm_32_389_5762_1_nw.laz',
#  '3dm_32_389_5763_1_nw.laz',
#  '3dm_32_389_5764_1_nw.laz',
#  '3dm_32_389_5765_1_nw.laz',
#  '3dm_32_389_5766_1_nw.laz',
#  '3dm_32_389_5767_1_nw.laz',
#  '3dm_32_389_5768_1_nw.laz',
#  '3dm_32_389_5769_1_nw.laz',
#  '3dm_32_389_5770_1_nw.laz',
#  '3dm_32_389_5771_1_nw.laz',
#  '3dm_32_389_5772_1_nw.laz',
#  '3dm_32_389_5773_1_nw.laz',
#  '3dm_32_389_5774_1_nw.laz',
#  '3dm_32_389_5775_1_nw.laz',
#  '3dm_32_389_5776_1_nw.laz',
#  '3dm_32_389_5777_1_nw.laz',
#  '3dm_32_389_5778_1_nw.laz',
#  '3dm_32_389_5779_1_nw.laz',
#  '3dm_32_389_5780_1_nw.laz',
#  '3dm_32_389_5781_1_nw.laz',
#  '3dm_32_389_5782_1_nw.laz',
#  '3dm_32_389_5783_1_nw.laz',
#  '3dm_32_389_5784_1_nw.laz',
#  '3dm_32_389_5785_1_nw.laz',
#  '3dm_32_389_5786_1_nw.laz',
#  '3dm_32_389_5787_1_nw.laz',
#  '3dm_32_389_5788_1_nw.laz',
#  '3dm_32_389_5789_1_nw.laz',
#  '3dm_32_389_5790_1_nw.laz',
#  '3dm_32_389_5791_1_nw.laz',
#  '3dm_32_389_5792_1_nw.laz',
#  '3dm_32_389_5793_1_nw.laz',
#  '3dm_32_389_5794_1_nw.laz',
#  '3dm_32_389_5795_1_nw.laz',
#  '3dm_32_389_5796_1_nw.laz',
#  '3dm_32_389_5797_1_nw.laz',
#  '3dm_32_390_5726_1_nw.laz',
#  '3dm_32_390_5727_1_nw.laz',
#  '3dm_32_390_5728_1_nw.laz',
#  '3dm_32_390_5729_1_nw.laz',
#  '3dm_32_390_5730_1_nw.laz',
#  '3dm_32_390_5731_1_nw.laz',
#  '3dm_32_390_5732_1_nw.laz',
#  '3dm_32_390_5733_1_nw.laz',
#  '3dm_32_390_5734_1_nw.laz',
#  '3dm_32_390_5735_1_nw.laz',
#  '3dm_32_390_5736_1_nw.laz',
#  '3dm_32_390_5737_1_nw.laz',
#  '3dm_32_390_5738_1_nw.laz',
#  '3dm_32_390_5739_1_nw.laz',
#  '3dm_32_390_5740_1_nw.laz',
#  '3dm_32_390_5741_1_nw.laz',
#  '3dm_32_390_5742_1_nw.laz',
#  '3dm_32_390_5743_1_nw.laz',
#  '3dm_32_390_5744_1_nw.laz',
#  '3dm_32_390_5745_1_nw.laz',
#  '3dm_32_390_5746_1_nw.laz',
#  '3dm_32_390_5747_1_nw.laz',
#  '3dm_32_390_5748_1_nw.laz',
#  '3dm_32_390_5749_1_nw.laz',
#  '3dm_32_390_5750_1_nw.laz',
#  '3dm_32_390_5751_1_nw.laz',
#  '3dm_32_390_5752_1_nw.laz',
#  '3dm_32_390_5753_1_nw.laz',
#  '3dm_32_390_5754_1_nw.laz',
#  '3dm_32_390_5755_1_nw.laz',
#  '3dm_32_390_5756_1_nw.laz',
#  '3dm_32_390_5757_1_nw.laz',
#  '3dm_32_390_5758_1_nw.laz',
#  '3dm_32_390_5759_1_nw.laz',
#  '3dm_32_390_5760_1_nw.laz',
#  '3dm_32_390_5761_1_nw.laz',
#  '3dm_32_390_5762_1_nw.laz',
#  '3dm_32_390_5763_1_nw.laz',
#  '3dm_32_390_5764_1_nw.laz',
#  '3dm_32_390_5765_1_nw.laz',
#  '3dm_32_390_5766_1_nw.laz',
#  '3dm_32_390_5767_1_nw.laz',
#  '3dm_32_390_5768_1_nw.laz',
#  '3dm_32_390_5769_1_nw.laz',
#  '3dm_32_390_5770_1_nw.laz',
#  '3dm_32_390_5771_1_nw.laz',
#  '3dm_32_390_5772_1_nw.laz',
#  '3dm_32_390_5773_1_nw.laz',
#  '3dm_32_390_5774_1_nw.laz',
#  '3dm_32_390_5775_1_nw.laz',
#  '3dm_32_390_5776_1_nw.laz',
#  '3dm_32_390_5777_1_nw.laz',
#  '3dm_32_390_5778_1_nw.laz',
#  '3dm_32_390_5779_1_nw.laz',
#  '3dm_32_390_5780_1_nw.laz',
#  '3dm_32_390_5781_1_nw.laz',
#  '3dm_32_390_5782_1_nw.laz',
#  '3dm_32_390_5783_1_nw.laz',
#  '3dm_32_390_5784_1_nw.laz',
#  '3dm_32_390_5785_1_nw.laz',
#  '3dm_32_390_5786_1_nw.laz',
#  '3dm_32_390_5787_1_nw.laz',
#  '3dm_32_390_5788_1_nw.laz',
#  '3dm_32_390_5789_1_nw.laz',
#  '3dm_32_390_5790_1_nw.laz',
#  '3dm_32_390_5791_1_nw.laz',
#  '3dm_32_390_5792_1_nw.laz',
#  '3dm_32_390_5793_1_nw.laz',
#  '3dm_32_390_5794_1_nw.laz',
#  '3dm_32_390_5795_1_nw.laz',
#  '3dm_32_390_5796_1_nw.laz',
#  '3dm_32_390_5797_1_nw.laz',
#  '3dm_32_391_5726_1_nw.laz',
#  '3dm_32_391_5727_1_nw.laz',
#  '3dm_32_391_5728_1_nw.laz',
#  '3dm_32_391_5729_1_nw.laz',
#  '3dm_32_391_5730_1_nw.laz',
#  '3dm_32_391_5731_1_nw.laz',
#  '3dm_32_391_5732_1_nw.laz',
#  '3dm_32_391_5733_1_nw.laz',
#  '3dm_32_391_5734_1_nw.laz',
#  '3dm_32_391_5735_1_nw.laz',
#  '3dm_32_391_5736_1_nw.laz',
#  '3dm_32_391_5737_1_nw.laz',
#  '3dm_32_391_5738_1_nw.laz',
#  '3dm_32_391_5739_1_nw.laz',
#  '3dm_32_391_5740_1_nw.laz',
#  '3dm_32_391_5741_1_nw.laz',
#  '3dm_32_391_5742_1_nw.laz',
#  '3dm_32_391_5743_1_nw.laz',
#  '3dm_32_391_5744_1_nw.laz',
#  '3dm_32_391_5745_1_nw.laz',
#  '3dm_32_391_5746_1_nw.laz',
#  '3dm_32_391_5747_1_nw.laz',
#  '3dm_32_391_5748_1_nw.laz',
#  '3dm_32_391_5749_1_nw.laz',
#  '3dm_32_391_5750_1_nw.laz',
#  '3dm_32_391_5751_1_nw.laz',
#  '3dm_32_391_5752_1_nw.laz',
#  '3dm_32_391_5753_1_nw.laz',
#  '3dm_32_391_5754_1_nw.laz',
#  '3dm_32_391_5755_1_nw.laz',
#  '3dm_32_391_5756_1_nw.laz',
#  '3dm_32_391_5757_1_nw.laz',
#  '3dm_32_391_5758_1_nw.laz',
#  '3dm_32_391_5759_1_nw.laz',
#  '3dm_32_391_5760_1_nw.laz',
#  '3dm_32_391_5761_1_nw.laz',
#  '3dm_32_391_5762_1_nw.laz',
#  '3dm_32_391_5763_1_nw.laz',
#  '3dm_32_391_5764_1_nw.laz',
#  '3dm_32_391_5765_1_nw.laz',
#  '3dm_32_391_5766_1_nw.laz',
#  '3dm_32_391_5767_1_nw.laz',
#  '3dm_32_391_5768_1_nw.laz',
#  '3dm_32_391_5769_1_nw.laz',
#  '3dm_32_391_5770_1_nw.laz',
#  '3dm_32_391_5771_1_nw.laz',
#  '3dm_32_391_5772_1_nw.laz',
#  '3dm_32_391_5773_1_nw.laz',
#  '3dm_32_391_5774_1_nw.laz',
#  '3dm_32_391_5775_1_nw.laz',
#  '3dm_32_391_5776_1_nw.laz',
#  '3dm_32_391_5777_1_nw.laz',
#  '3dm_32_391_5778_1_nw.laz',
#  '3dm_32_391_5779_1_nw.laz',
#  '3dm_32_391_5780_1_nw.laz',
#  '3dm_32_391_5781_1_nw.laz',
#  '3dm_32_391_5782_1_nw.laz',
#  '3dm_32_391_5783_1_nw.laz',
#  '3dm_32_391_5784_1_nw.laz',
#  '3dm_32_391_5785_1_nw.laz',
#  '3dm_32_391_5786_1_nw.laz',
#  '3dm_32_391_5787_1_nw.laz',
#  '3dm_32_391_5788_1_nw.laz',
#  '3dm_32_391_5789_1_nw.laz',
#  '3dm_32_391_5790_1_nw.laz',
#  '3dm_32_391_5791_1_nw.laz',
#  '3dm_32_391_5792_1_nw.laz',
#  '3dm_32_391_5793_1_nw.laz',
#  '3dm_32_391_5794_1_nw.laz',
#  '3dm_32_391_5795_1_nw.laz',
#  '3dm_32_391_5796_1_nw.laz',
#  '3dm_32_391_5797_1_nw.laz',
#  '3dm_32_392_5726_1_nw.laz',
#  '3dm_32_392_5727_1_nw.laz',
#  '3dm_32_392_5728_1_nw.laz',
#  '3dm_32_392_5729_1_nw.laz',
#  '3dm_32_392_5730_1_nw.laz',
#  '3dm_32_392_5731_1_nw.laz',
#  '3dm_32_392_5732_1_nw.laz',
#  '3dm_32_392_5733_1_nw.laz',
#  '3dm_32_392_5734_1_nw.laz',
#  '3dm_32_392_5735_1_nw.laz',
#  '3dm_32_392_5736_1_nw.laz',
#  '3dm_32_392_5737_1_nw.laz',
#  '3dm_32_392_5738_1_nw.laz',
#  '3dm_32_392_5739_1_nw.laz',
#  '3dm_32_392_5740_1_nw.laz',
#  '3dm_32_392_5741_1_nw.laz',
#  '3dm_32_392_5742_1_nw.laz',
#  '3dm_32_392_5743_1_nw.laz',
#  '3dm_32_392_5744_1_nw.laz',
#  '3dm_32_392_5745_1_nw.laz',
#  '3dm_32_392_5746_1_nw.laz',
#  '3dm_32_392_5747_1_nw.laz',
#  '3dm_32_392_5748_1_nw.laz',
#  '3dm_32_392_5749_1_nw.laz',
#  '3dm_32_392_5750_1_nw.laz',
#  '3dm_32_392_5751_1_nw.laz',
#  '3dm_32_392_5752_1_nw.laz',
#  '3dm_32_392_5753_1_nw.laz',
#  '3dm_32_392_5754_1_nw.laz',
#  '3dm_32_392_5755_1_nw.laz',
#  '3dm_32_392_5756_1_nw.laz',
#  '3dm_32_392_5757_1_nw.laz',
#  '3dm_32_392_5758_1_nw.laz',
#  '3dm_32_392_5759_1_nw.laz',
#  '3dm_32_392_5760_1_nw.laz',
#  '3dm_32_392_5761_1_nw.laz',
#  '3dm_32_392_5762_1_nw.laz',
#  '3dm_32_392_5763_1_nw.laz',
#  '3dm_32_392_5764_1_nw.laz',
#  '3dm_32_392_5765_1_nw.laz',
#  ...]

# %%
# !zip results.zip *.txt
# Out:
#   adding: zone_1.1_files.txt (deflated 90%)
#   adding: zone_1.2_files.txt (deflated 90%)
#   adding: zone_1.3_files.txt (deflated 90%)
#   adding: zone_1.4_files.txt (deflated 90%)
#   adding: zone_2.1_files.txt (deflated 90%)
#   adding: zone_2.2_files.txt (deflated 89%)
#   adding: zone_2.3_files.txt (deflated 90%)
#   adding: zone_2.4_files.txt (deflated 90%)
#   adding: zone_3.1_files.txt (deflated 90%)
#   adding: zone_3.2_files.txt (deflated 90%)
#   adding: zone_3.3_files.txt (deflated 90%)
#   adding: zone_3.4_files.txt (deflated 90%)
#   adding: zone_4.1_files.txt (deflated 90%)
#   adding: zone_4.2_files.txt (deflated 91%)
#   adding: zone_4.3_files.txt (deflated 91%)
#   adding: zone_4.4_files.txt (deflated 90%)

# %% [markdown]
# # Generate a KML file showing our division in subzones

# %%
import simplekml
import utm

def utm_to_latlon(x, y):
    # Convert lat/lon to UTM coordinates
    lat, lon = utm.to_latlon((x - 32000)*1000, y*1000, 32, 'U')

    return lat, lon

def create_kml_with_squares(coordinates, kml_filename):
    """
    Create a KML file with squares from a list of coordinates.
    """
    kml = simplekml.Kml()

    for min_easting, max_easting, min_northing, max_northing in coordinates:
        # Convert each corner to WGS84
        min_lat, min_lon = utm_to_latlon(min_easting, min_northing)
        max_lat, max_lon = utm_to_latlon(max_easting, max_northing)

        # Create square as a polygon
        pol = kml.newpolygon(name="Square",
                             outerboundaryis=[(min_lon, min_lat),
                                              (min_lon, max_lat),
                                              (max_lon, max_lat),
                                              (max_lon, min_lat),
                                              (min_lon, min_lat)])
        pol.style.linestyle.color = simplekml.Color.red
        pol.style.linestyle.width = 3
        pol.style.polystyle.color = simplekml.Color.changealphaint(100, simplekml.Color.green)

    kml.save(kml_filename)

# %%
create_kml_with_squares(coordinates, 'NRW_division.kml')

# %% [markdown]
# # Download

# %%
url_prefix = 'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/'

download_list = [url_prefix + item for item in sub_zones[1]['zone_2.3']]

# %%
download_list
# Out:
# ['https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_280_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_281_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_282_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_283_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_284_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_285_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_286_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_287_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_288_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_289_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_290_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_291_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_292_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_293_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_294_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_295_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_296_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_297_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5684_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_298_5685_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_299_5662_1_nw.laz',
# ...
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_306_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_306_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_306_5684_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_306_5685_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5670_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5671_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5684_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_307_5685_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5670_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5671_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5684_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_308_5685_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5639_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5640_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5641_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5642_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5643_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5644_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5645_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5646_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5647_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5648_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5649_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5650_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5651_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5652_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5653_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5654_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5655_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5656_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5657_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5658_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5659_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5660_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5661_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5662_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5663_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5664_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5665_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5666_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5667_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5668_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5669_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5670_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5671_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5672_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5673_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5674_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5675_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5676_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5677_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5678_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5679_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5680_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5681_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5682_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5683_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5684_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_309_5685_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_310_5636_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_310_5637_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_310_5638_1_nw.laz',
#  'https://www.opengeodata.nrw.de/produkte/geobasis/hm/3dm_l_las/3dm_l_las/3dm_32_310_5639_1_nw.laz',
#  ...]

# %%
import requests
from time import sleep
import os
from tqdm import tqdm

def download_file(url, directory, attempt=1, max_attempts=5):

    file_name = url.split('/')[-1]
    file_path = os.path.join(directory, file_name)  # Combine the directory with the file name

    # Check if the file already exists
    if os.path.exists(file_path):
        #print(f"File {file_name} already exists in {directory}. Skipping download.")
        return

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Raise an error for bad status codes

        with open(file_path, 'wb') as file:
            file.write(response.content)
        #print(f"Downloaded {file_name} to {directory}")

    except requests.RequestException as e:
        if attempt < max_attempts:
            print(f"Attempt {attempt} failed for {url}. Retrying...")
            sleep(1)  # Wait for 1 second before retrying
            download_file(url, directory, attempt + 1, max_attempts)
        else:
            print(f"Failed to download {url} after {max_attempts} attempts.")

download_directory = "/Volumes/SSD2/Split_NRW/zone_2.3/"

# Create the directory if it doesn't exist
if not os.path.exists(download_directory):
    os.makedirs(download_directory)

# Download each file
for url in tqdm(download_list):
    download_file(url, download_directory)
# Out:
# 100%|██████████| 1572/1572 [5:09:34<00:00, 11.82s/it]

# %% [markdown]
# # Create a download list for DEM files

# %%
def generate_url(filename):
    # Split the filename to extract the required parts
    parts = filename.split('_')
    xxx = parts[2]
    yyyy = parts[3]

    # Calculate zzz and qqqq
    aaa = str(int(xxx) + 1).zfill(len(xxx))
    bbbb = str(int(yyyy) + 1).zfill(len(yyyy))

    # Construct and return the URL
    url = f"https://www.wcs.nrw.de/geobasis/wcs_nw_dgm?REQUEST=GetCoverage&SERVICE=WCS&VERSION=2.0.1&COVERAGEID=nw_dgm&FORMAT=image/tiff&SUBSET=x({xxx}000,{aaa}000)&SUBSET=y({yyyy}000,{bbbb}000)&OUTFILE=dgm1_32_{xxx}_{yyyy}_1_nw&APP=timonline"
    return url

# %%
# Example usage
filename = '3dm_32_286_5630_1_nw.laz'
url = generate_url(filename)
url

# %%
def write_dem_download_lists(zones):
    for zone, filenames in zones.items():
        with open(f'./download_lists/{zone}_DEM_files.txt', 'w') as file:
            for filename in filenames:
                url = generate_url(filename)
                file.write(url + '\n')

# %%
write_dem_download_lists(sub_zones[0])

# %% [markdown]
# # Download DEM files

# %%
def load_file_to_list(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
        # Strip newline characters from each line
        lines = [line.strip() for line in lines]
    return lines

# %%
dem_download_list = load_file_to_list('./download_lists/zone_1.4_DEM_files.txt')

# %%
import requests
from time import sleep
import os
from tqdm import tqdm

def find_filename(url):
    params = url.split('&')

    for param in params:
        if param.startswith('OUTFILE='):
            # Extracting and returning the value of OUTFILE
            return param.split('=')[1] + '.tif'

    # Return None if OUTFILE is not found
    return None

def download_file(url, directory, attempt=1, max_attempts=5):
    """Download a file with retries on failure and save it to a specified directory."""
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Raise an error for bad status codes

        file_name = find_filename(url)
        file_path = os.path.join(directory, file_name)  # Combine the directory with the file name

        with open(file_path, 'wb') as file:
            file.write(response.content)
        #print(f"Downloaded {file_name} to {directory}")

    except requests.RequestException as e:
        if attempt < max_attempts:
            #print(f"Attempt {attempt} failed for {url}. Retrying...")
            sleep(1)  # Wait for 1 second before retrying
            download_file(url, directory, attempt + 1, max_attempts)
        else:
            print(f"Failed to download {url} after {max_attempts} attempts.")

download_directory = "/Volumes/SSD2/Split_NRW/zone_1.4_DEM/"

# Create the directory if it doesn't exist
if not os.path.exists(download_directory):
    os.makedirs(download_directory)

# Download each file
for url in tqdm(dem_download_list):
    download_file(url, download_directory)
# Out:
#   0%|          | 0/2416 [00:00<?, ?it/s]
# 100%|██████████| 2416/2416 [44:49<00:00,  1.11s/it]
